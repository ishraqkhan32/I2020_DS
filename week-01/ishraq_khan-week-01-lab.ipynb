# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Extended Lab</h1>
# </div>

# %% [markdown]
# ### Question 1:
#
# Explain what data types are in your own words.

# %% [markdown]
# Data types are the form in which data is stored digitally. Some langauges require you to specify the data type beforehand (like C++), while others are dynamically typed (like Python). Common data types are integers, strings, floats, characters, and arrays.

# %% [markdown]
# ## Question 2:
#
# In your own words, explain what a float is and why sometimes it gives an incorrect value.

# %% [markdown]
# A float is a data type in programming langauges for numbers with decimal points. They are used when you need more precision. Python treats floats (decimal numbers) like C and Java and stores them using a fixed number of binary digits. However, some numbers can't be stored using binary digits so this causes problems with calculations.

# %% [markdown]
# ### Exercise 1:
#
# Store your first name, in lowercase, in a variable.
# Using that one variable, print your name in lowercase, Titlecase, and UPPERCASE.

# %%
my_name = "ishraq"
print(my_name.lower())
print(my_name.title())
print(my_name.upper())
# Out:
# ishraq
# Ishraq
# ISHRAQ

# %% [markdown]
# ### Exercise 2:
#
# Find a quote that you like. Store the quote in a variable, with an appropriate introduction such as "Ken Thompson once said, 'One of my most productive days was throwing away 1000 lines of code'". Print the quote 1000 times.

# %%
my_quote = "Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'"
for i in range(1000):
    print(my_quote)
# Out:
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# Benjamin P. Hardy once said, 'Ordinary people seek entertainment. Extraordinary people seek education and learning.'
# ...

# %% [markdown]
# ### Exercise 3:
#
# Use python string operations and methods to use the following variables to print this:
#
#     "hello world"

# %%
message_1 = "hELlo"
message_2 = "                              wor"
message_3 = "wbdaloqteldndyrcggzf"

print(message_1.lower(), message_2[-3:].strip() + message_3[9:11])
# Out:
# hello world

# %% [markdown]
# ### Exercise 4
#
# Fix the following code so it prints properly

# %%
# Dollar amounts should only have two digits after the decimal
print("The price is $%.2f." % 3.44444)
# Out:
# The price is $3.44.

# %%
# Complete the code so it prints your name and what you're learning
name = input("enter your name: ")
language = input("enter the language you are learning: ")
print("{} is learning {}".format(name, language) )
# Out:
# enter your name: ishraq
# enter the language you are learning: python
# ishraq is learning python

# %% [markdown]
# ### Exercise 5
#
# Create your own mad-lib with at least 5 inputs.

# %%
location = input("enter a location")
noun = input("enter a noun")
time_of_day = input("enter a time of day")
adjective = input("enter a adjective")
animal = input("enter a animal")

madlib = f"Today I went to the {location}. I saw a {noun} on a scooter. It was {time_of_day} in the day so I decided to leave {adjective}, but a {animal} followed me home. It snarled at me and said 'Ishraq it's time to wake up!'"
print(madlib)
# Out:
# enter a locationzoo
# enter a nounraccoon
# enter a time of daysunset
# enter a adjectivequickly
# enter a animallizard
# Today I went to the zoo. I saw a raccoon on a scooter. It was sunset in the day so I decided to leave quickly, but a lizard followed me home. It snarled at me and said 'Ishraq it's time to wake up!'
